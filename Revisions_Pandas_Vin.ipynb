# %% [markdown]
# <a href="https://colab.research.google.com/github/Lovelylove03/-my_streamlit12_app.py/blob/main/Revisions_Pandas_Vin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Revision : Boutique de vin

# %%
import pandas as pd

# %%
link1 = 'https://github.com/Fully-san/WildCodeSchool/tree/master/vin/erp.xlsx'
link2 = 'https://github.com/Fully-san/WildCodeSchool/tree/master/vin/liaison.xlsx'
link3 = "https://github.com/Fully-san/WildCodeSchool/tree/master/vin/web.xlsx"

# %% [markdown]
# **Datasets** :<br>
# erp.xlsx : https://github.com/Fully-san/WildCodeSchool/tree/master/vin/erp.xlsx<br>
# liaison.xlsx : https://github.com/Fully-san/WildCodeSchool/tree/master/vin/liaison.xlsx<br>
# web.xlsx : https://github.com/Fully-san/WildCodeSchool/tree/master/vin/web.xlsx

# %%
dfErp = pd.read_excel(link1, engine = 'openpyxl')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-acbf0cfae8d7> in <cell line: 1>()
# ----> 1 dfErp = pd.read_excel(link1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     if not isinstance(io, ExcelFile):
#     503         should_close = True
# --> 504         io = ExcelFile(
#     505             io,
#     506             storage_options=storage_options,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1565                 )
# ...

# %%
dfErp
# Out:
#      product_id  onsale_web  price  stock_quantity stock_status
# 0          3847           1   24.2               0   outofstock
# 1          3849           1   34.3               0   outofstock
# 2          3850           1   20.8               0   outofstock
# 3          4032           1   14.1               0   outofstock
# 4          4039           1   46.0               0   outofstock
# ..          ...         ...    ...             ...          ...
# 820        7203           0   45.0              30      instock
# 821        7204           0   45.0               9      instock
# 822        7247           1   54.8              23      instock
# 823        7329           0   26.5              14      instock
# 824        7338           1   16.3              45      instock
#
# [825 rows x 5 columns]

# %% [markdown]
# Le Dataset comporte plusieurs corruptions ou des erreurs, identifiez un maximum et si vous avez le temps essayez de trouvez les tendances principales.
