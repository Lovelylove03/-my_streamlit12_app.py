# %% [markdown]
# # Revision : Boutique de vin

# %%
import pandas as pd

# %%
link1 = 'https://github.com/Fully-san/WildCodeSchool/tree/master/vin/erp.xlsx'
link2 = 'https://github.com/Fully-san/WildCodeSchool/tree/master/vin/liaison.xlsx'
link3 = "https://github.com/Fully-san/WildCodeSchool/tree/master/vin/web.xlsx"

# %% [markdown]
# **Datasets** :<br>
# erp.xlsx : https://github.com/Fully-san/WildCodeSchool/tree/master/vin/erp.xlsx<br>
# liaison.xlsx : https://github.com/Fully-san/WildCodeSchool/tree/master/vin/liaison.xlsx<br>
# web.xlsx : https://github.com/Fully-san/WildCodeSchool/tree/master/vin/web.xlsx

# %%
import pandas as pd

# Correct URL format for raw Excel file from GitHub
file_url = 'https://github.com/Fully-san/WildCodeSchool/raw/master/vin/erp.xlsx'

# Use pd.read_excel to read the Excel file
df = pd.read_excel(file_url)

# Display the dataframe
df
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#      product_id  onsale_web  price  stock_quantity stock_status
# 0          3847           1   24.2               0   outofstock
# 1          3849           1   34.3               0   outofstock
# 2          3850           1   20.8               0   outofstock
# 3          4032           1   14.1               0   outofstock
# 4          4039           1   46.0               0   outofstock
# ..          ...         ...    ...             ...          ...
# 820        7203           0   45.0              30      instock
# 821        7204           0   45.0               9      instock
# 822        7247           1   54.8              23      instock
# 823        7329           0   26.5              14      instock
# 824        7338           1   16.3              45      instock
#
# [825 rows x 5 columns]

# %% [markdown]
# Le Dataset comporte plusieurs corruptions ou des erreurs, identifiez un maximum et si vous avez le temps essayez de trouvez les tendances principales.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      825 non-null    int64
#  1   onsale_web      825 non-null    int64
#  2   price           825 non-null    float64
#  3   stock_quantity  825 non-null    int64
#  4   stock_status    825 non-null    object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 32.4+ KB

# %%
df.isnull().sum()
# Out:
# product_id        0
# onsale_web        0
# price             0
# stock_quantity    0
# stock_status      0
# dtype: int64

# %%
import matplotlib.pyplot as plt
df.hist(figsize=(10,10))
plt.show()

# %%
df.describe()
# Out:
#         product_id  onsale_web       price  stock_quantity
# count   825.000000  825.000000  825.000000      825.000000
# mean   5162.597576    0.869091   32.415636       26.496970
# std     902.644635    0.337506   26.795849       45.892422
# min    3847.000000    0.000000    5.200000        0.000000
# 25%    4348.000000    1.000000   14.600000        1.000000
# 50%    4907.000000    1.000000   24.400000       11.000000
# 75%    5805.000000    1.000000   42.000000       34.000000
# max    7338.000000    1.000000  225.000000      578.000000

# %%
# Select only the numerical columns
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Compute the correlation matrix
correlation_matrix = numeric_df.corr()

# Display the correlation matrix
correlation_matrix
# Out:
#                 product_id  onsale_web     price  stock_quantity
# product_id        1.000000   -0.372854  0.112821       -0.108501
# onsale_web       -0.372854    1.000000  0.030876        0.119618
# price             0.112821    0.030876  1.000000       -0.275648
# stock_quantity   -0.108501    0.119618 -0.275648        1.000000

# %% [markdown]
# nterpretation of Each Pairwise Correlation:
# product_id and onsale_web:
#
# Correlation: -0.3728
# Interpretation: There is a moderate negative correlation between product_id and onsale_web. This could suggest that as product_id values increase, the likelihood of the product being on sale (onsale_web) tends to decrease, though the relationship is not very strong.
# product_id and price:
#
# Correlation: 0.1128
# Interpretation: There is a very weak positive correlation between product_id and price, implying that there is almost no linear relationship between product IDs and their prices.
# product_id and stock_quantity:
#
# Correlation: -0.1085
# Interpretation: There is a very weak negative correlation between product_id and stock_quantity, indicating almost no linear relationship between product IDs and stock quantities.
# onsale_web and price:
#
# Correlation: 0.0309
# Interpretation: There is an extremely weak positive correlation between whether a product is on sale and its price. This indicates no meaningful linear relationship between these two variables.
# onsale_web and stock_quantity:
#
# Correlation: 0.1196
# Interpretation: There is a very weak positive correlation between whether a product is on sale and its stock quantity. This suggests a minimal, almost negligible, linear relationship.
# price and stock_quantity:
#
# Correlation: -0.2756
# Interpretation: There is a weak negative correlation between price and stock quantity. This suggests that, generally, as the price increases, the stock quantity tends to decrease, though the relationship is not very strong.
# Summary:
# Most of the correlations in this matrix are weak, indicating that the variables do not have strong linear relationships with one another. The only somewhat notable correlation is between product_id and onsale_web, which suggests that as product IDs increase, the products are slightly less likely to be on sale. However, even this relationship is moderate at best.

# %%
import pandas as pd

# Correct URL for the raw Excel file on GitHub
file_url = 'https://github.com/Fully-san/WildCodeSchool/raw/master/vin/liaison.xlsx'

# Specify the engine if needed
df1 = pd.read_excel(file_url, engine='openpyxl')

# Display the dataframe
df1
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#      product_id   id_web
# 0          3847    15298
# 1          3849    15296
# 2          3850    15300
# 3          4032    19814
# 4          4039    19815
# ..          ...      ...
# 820        7203      NaN
# 821        7204      NaN
# 822        7247  13127-1
# 823        7329  14680-1
# 824        7338    16230
#
# [825 rows x 2 columns]

# %%
df1.shape
# Out:
# (825, 2)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   product_id  825 non-null    int64
#  1   id_web      734 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 13.0+ KB

# %%
df1.isnull().sum()
# Out:
# product_id     0
# id_web        91
# dtype: int64

# %%
df.describe()
# Out:
#         product_id  onsale_web       price  stock_quantity
# count   825.000000  825.000000  825.000000      825.000000
# mean   5162.597576    0.869091   32.415636       26.496970
# std     902.644635    0.337506   26.795849       45.892422
# min    3847.000000    0.000000    5.200000        0.000000
# 25%    4348.000000    1.000000   14.600000        1.000000
# 50%    4907.000000    1.000000   24.400000       11.000000
# 75%    5805.000000    1.000000   42.000000       34.000000
# max    7338.000000    1.000000  225.000000      578.000000

# %%
df.columns
# Out:
# Index(['product_id', 'onsale_web', 'price', 'stock_quantity', 'stock_status'], dtype='object')

# %%
df1['missing_flag'] = df1['id_web'].isna().astype(int)
df1['missing_flag'].value_counts()
# Out:
# missing_flag
# 0    734
# 1     91
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.heatmap(df1.isna(),  cbar=False)
# Out:
# <Axes: >

# %%
df_cl = df1.dropna(axis=1)
df_cl.head()
# Out:
#    product_id  missing_flag
# 0        3847             0
# 1        3849             0
# 2        3850             0
# 3        4032             0
# 4        4039             0

# %%
df_cl.isnull().sum()
# Out:
# product_id      0
# missing_flag    0
# dtype: int64

# %%
# Merge the two DataFrames on the 'product_id' column using an inner join
merged_df = pd.merge(df, df_cl, on='product_id', how='inner')

# Display the merged DataFrame
merged_df
# Out:
#      product_id  onsale_web  price  stock_quantity stock_status  missing_flag
# 0          3847           1   24.2               0   outofstock             0
# 1          3849           1   34.3               0   outofstock             0
# 2          3850           1   20.8               0   outofstock             0
# 3          4032           1   14.1               0   outofstock             0
# 4          4039           1   46.0               0   outofstock             0
# ..          ...         ...    ...             ...          ...           ...
# 820        7203           0   45.0              30      instock             1
# 821        7204           0   45.0               9      instock             1
# 822        7247           1   54.8              23      instock             0
# 823        7329           0   26.5              14      instock             0
# 824        7338           1   16.3              45      instock             0
#
# [825 rows x 6 columns]

# %%
merged_df.shape
# Out:
# (825, 6)

# %%
merged_df.isnull().sum()
# Out:
# product_id        0
# onsale_web        0
# price             0
# stock_quantity    0
# stock_status      0
# missing_flag      0
# dtype: int64

# %%
import pandas as pd

# Correct URL for the raw Excel file on GitHub
file_url = 'https://github.com/Fully-san/WildCodeSchool/raw/master/vin/web.xlsx'

# Load the Excel file using the correct URL
df3 = pd.read_excel(file_url, engine='openpyxl')

# Display the dataframe
df3
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                       sku  virtual  downloadable  rating_count  \
# 0     bon-cadeau-25-euros        0             0             0
# 1                   15298        0             0             0
# 2                   15296        0             0             0
# 3                   15300        0             0             0
# 4                   19814        0             0             0
# ...                   ...      ...           ...           ...
# 1508                16135        0             0             0
# 1509                15891        0             0             0
# 1510                15887        0             0             0
# 1511              13127-1        0             0             0
# 1512                16230        0             0             0
#
# ...

# %%
df3.shape
# Out:
# (1513, 28)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1513 entries, 0 to 1512
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   sku                    1428 non-null   object
#  1   virtual                1513 non-null   int64
#  2   downloadable           1513 non-null   int64
#  3   rating_count           1513 non-null   int64
#  4   average_rating         1430 non-null   float64
#  5   total_sales            1430 non-null   float64
#  6   tax_status             716 non-null    object
#  7   tax_class              0 non-null      float64
#  8   post_author            1430 non-null   float64
#  9   post_date              1430 non-null   datetime64[ns]
#  10  post_date_gmt          1430 non-null   datetime64[ns]
#  11  post_content           0 non-null      float64
#  12  post_title             1430 non-null   object
#  13  post_excerpt           716 non-null    object
# ...

# %%
df3.isnull().sum()
# Out:
# sku                        85
# virtual                     0
# downloadable                0
# rating_count                0
# average_rating             83
# total_sales                83
# tax_status                797
# tax_class                1513
# post_author                83
# post_date                  83
# post_date_gmt              83
# post_content             1513
# post_title                 83
# post_excerpt              797
# post_status                83
# comment_status             83
# ping_status                83
# post_password            1513
# post_name                  83
# post_modified              83
# post_modified_gmt          83
# post_content_filtered    1513
# post_parent                83
# guid                       83
# menu_order                 83
# post_type                  83
# post_mime_type            799
# comment_count              83
# dtype: int64

# %%
# Display percentage of missing values per column
nan_percentage = (df.isna().mean() * 100)
nan_percentage = nan_percentage.sort_values(ascending=False)
nan_percentage
# Out:
# product_id        0.0
# onsale_web        0.0
# price             0.0
# stock_quantity    0.0
# stock_status      0.0
# dtype: float64

# %%
heatmap_data = df3.isnull()
sns.heatmap(heatmap_data, cbar=False,cmap="viridis")
plt.show()

# %%
# Drop rows with a large number of NaN values
cleaned = df3.dropna(thresh=3)  # Keep rows with at least 3 non-NaN values
cleaned
# Out:
#                       sku  virtual  downloadable  rating_count  \
# 0     bon-cadeau-25-euros        0             0             0
# 1                   15298        0             0             0
# 2                   15296        0             0             0
# 3                   15300        0             0             0
# 4                   19814        0             0             0
# ...                   ...      ...           ...           ...
# 1508                16135        0             0             0
# 1509                15891        0             0             0
# 1510                15887        0             0             0
# 1511              13127-1        0             0             0
# 1512                16230        0             0             0
#
#       average_rating  total_sales tax_status  tax_class  post_author  \
# 0                0.0         10.0    taxable        NaN          1.0
# ...

# %%
cleaned.isnull().sum()
# Out:
# sku                        85
# virtual                     0
# downloadable                0
# rating_count                0
# average_rating             83
# total_sales                83
# tax_status                797
# tax_class                1513
# post_author                83
# post_date                  83
# post_date_gmt              83
# post_content             1513
# post_title                 83
# post_excerpt              797
# post_status                83
# comment_status             83
# ping_status                83
# post_password            1513
# post_name                  83
# post_modified              83
# post_modified_gmt          83
# post_content_filtered    1513
# post_parent                83
# guid                       83
# menu_order                 83
# post_type                  83
# post_mime_type            799
# comment_count              83
# dtype: int64

# %%
cleaned.columns
# Out:
# Index(['sku', 'virtual', 'downloadable', 'rating_count', 'average_rating',
#        'total_sales', 'tax_status', 'tax_class', 'post_author', 'post_date',
#        'post_date_gmt', 'post_content', 'post_title', 'post_excerpt',
#        'post_status', 'comment_status', 'ping_status', 'post_password',
#        'post_name', 'post_modified', 'post_modified_gmt',
#        'post_content_filtered', 'post_parent', 'guid', 'menu_order',
#        'post_type', 'post_mime_type', 'comment_count'],
#       dtype='object')

# %%
# Concatenate the DataFrames horizontally (combine columns)
final_df = pd.concat([merged_df, df3], axis=1)

# Check the combined DataFrame
final_df
# Out:
#       product_id  onsale_web  price  stock_quantity stock_status  \
# 0         3847.0         1.0   24.2             0.0   outofstock
# 1         3849.0         1.0   34.3             0.0   outofstock
# 2         3850.0         1.0   20.8             0.0   outofstock
# 3         4032.0         1.0   14.1             0.0   outofstock
# 4         4039.0         1.0   46.0             0.0   outofstock
# ...          ...         ...    ...             ...          ...
# 1508         NaN         NaN    NaN             NaN          NaN
# 1509         NaN         NaN    NaN             NaN          NaN
# 1510         NaN         NaN    NaN             NaN          NaN
# 1511         NaN         NaN    NaN             NaN          NaN
# 1512         NaN         NaN    NaN             NaN          NaN
#
#       missing_flag                  sku  virtual  downloadable  rating_count  \
# 0              0.0  bon-cadeau-25-euros        0             0             0
# ...

# %%
final_df.shape
# Out:
# (1513, 34)

# %%
final_df.columns
# Out:
# Index(['product_id', 'onsale_web', 'price', 'stock_quantity', 'stock_status',
#        'missing_flag', 'sku', 'virtual', 'downloadable', 'rating_count',
#        'average_rating', 'total_sales', 'tax_status', 'tax_class',
#        'post_author', 'post_date', 'post_date_gmt', 'post_content',
#        'post_title', 'post_excerpt', 'post_status', 'comment_status',
#        'ping_status', 'post_password', 'post_name', 'post_modified',
#        'post_modified_gmt', 'post_content_filtered', 'post_parent', 'guid',
#        'menu_order', 'post_type', 'post_mime_type', 'comment_count'],
#       dtype='object')

# %%
# Display percentage of missing values per column
nan_percentage = (final_df.isna().mean() * 100)
nan_percentage = nan_percentage.sort_values(ascending=False)
nan_percentage
# Out:
# post_content             100.000000
# post_content_filtered    100.000000
# post_password            100.000000
# tax_class                100.000000
# post_mime_type            52.808989
# tax_status                52.676801
# post_excerpt              52.676801
# onsale_web                45.472571
# product_id                45.472571
# stock_status              45.472571
# price                     45.472571
# stock_quantity            45.472571
# missing_flag              45.472571
# sku                        5.617978
# comment_status             5.485790
# post_type                  5.485790
# menu_order                 5.485790
# guid                       5.485790
# post_parent                5.485790
# post_modified_gmt          5.485790
# post_modified              5.485790
# post_name                  5.485790
# comment_count              5.485790
# ping_status                5.485790
# average_rating             5.485790
# post_status                5.485790
# ...

# %%
# Step 1: Drop columns with 100% missing values
revision = final_df.drop(columns=['post_content', 'post_content_filtered', 'post_password', 'tax_class'])

# %%
# Step 2: Drop columns with more than 50% missing values
revision1 = revision.drop(columns=['post_mime_type', 'tax_status', 'post_excerpt'])

# %%
df_cleaned = revision1

# %%
import pandas as pd
from sklearn.impute import KNNImputer

# Separate numerical and categorical columns
categorical_cols = df_cleaned.select_dtypes(include=['object']).columns
numerical_cols = df_cleaned.select_dtypes(include=['float64', 'int64']).columns

# Handle categorical columns - fill missing values with the mode (most frequent value)
for col in categorical_cols:
    df_cleaned[col].fillna(df_cleaned[col].mode()[0], inplace=True)

# Now apply KNN Imputer only on the numerical columns
imputer = KNNImputer(n_neighbors=5)
df_cleaned[numerical_cols] = imputer.fit_transform(df_cleaned[numerical_cols])

# After imputation, check the DataFrame to ensure everything is correct
print(df_cleaned.info())
# Out:
# <ipython-input-128-81fadb9c9993>:10: UserWarning: Unable to sort modes: '<' not supported between instances of 'int' and 'str'
#   df_cleaned[col].fillna(df_cleaned[col].mode()[0], inplace=True)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1513 entries, 0 to 1512
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_id         1513 non-null   float64
#  1   onsale_web         1513 non-null   float64
#  2   price              1513 non-null   float64
#  3   stock_quantity     1513 non-null   float64
#  4   stock_status       1513 non-null   object
#  5   missing_flag       1513 non-null   float64
#  6   sku                1513 non-null   object
#  7   virtual            1513 non-null   float64
#  8   downloadable       1513 non-null   float64
#  9   rating_count       1513 non-null   float64
#  10  average_rating     1513 non-null   float64
# ...

# %%
df_cleaned.isnull().sum()
# Out:
# product_id            0
# onsale_web            0
# price                 0
# stock_quantity        0
# stock_status          0
# missing_flag          0
# sku                   0
# virtual               0
# downloadable          0
# rating_count          0
# average_rating        0
# total_sales           0
# post_author           0
# post_date            83
# post_date_gmt        83
# post_title            0
# post_status           0
# comment_status        0
# ping_status           0
# post_name             0
# post_modified        83
# post_modified_gmt    83
# post_parent           0
# guid                  0
# menu_order            0
# post_type             0
# comment_count         0
# dtype: int64

# %%
nan_percentage = (df_cleaned.isna().mean() * 100)
nan_percentage = nan_percentage.sort_values(ascending=False)
nan_percentage
# Out:
# post_date            5.48579
# post_date_gmt        5.48579
# post_modified_gmt    5.48579
# post_modified        5.48579
# post_type            0.00000
# menu_order           0.00000
# guid                 0.00000
# post_parent          0.00000
# post_name            0.00000
# ping_status          0.00000
# comment_status       0.00000
# post_status          0.00000
# post_title           0.00000
# product_id           0.00000
# onsale_web           0.00000
# post_author          0.00000
# total_sales          0.00000
# average_rating       0.00000
# rating_count         0.00000
# downloadable         0.00000
# virtual              0.00000
# sku                  0.00000
# missing_flag         0.00000
# stock_status         0.00000
# stock_quantity       0.00000
# price                0.00000
# comment_count        0.00000
# dtype: float64

# %%
# Step 4: Simple imputation for columns with ~5% missing values
columns_with_low_missing = ['post_modified_gmt', 'post_modified', 'post_date_gmt', 'post_date']

# Impute missing values with the mode for categorical and median for numerical
for col in columns_with_low_missing:
    if df_cleaned[col].dtype == 'object':  # Categorical
        df_cleaned[col].fillna(df_cleaned[col].mode()[0], inplace=True)
    else:  # Numerical
        df_cleaned[col].fillna(df_cleaned[col].median(), inplace=True)

# Step 5: Ensure there are no remaining NaN values
df_cleaned = df_cleaned.dropna()

# %%
df_cleaned.isnull().sum()
# Out:
# product_id           0
# onsale_web           0
# price                0
# stock_quantity       0
# stock_status         0
# missing_flag         0
# sku                  0
# virtual              0
# downloadable         0
# rating_count         0
# average_rating       0
# total_sales          0
# post_author          0
# post_date            0
# post_date_gmt        0
# post_title           0
# post_status          0
# comment_status       0
# ping_status          0
# post_name            0
# post_modified        0
# post_modified_gmt    0
# post_parent          0
# guid                 0
# menu_order           0
# post_type            0
# comment_count        0
# dtype: int64

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1513 entries, 0 to 1512
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_id         1513 non-null   float64
#  1   onsale_web         1513 non-null   float64
#  2   price              1513 non-null   float64
#  3   stock_quantity     1513 non-null   float64
#  4   stock_status       1513 non-null   object
#  5   missing_flag       1513 non-null   float64
#  6   sku                1513 non-null   object
#  7   virtual            1513 non-null   float64
#  8   downloadable       1513 non-null   float64
#  9   rating_count       1513 non-null   float64
#  10  average_rating     1513 non-null   float64
#  11  total_sales        1513 non-null   float64
#  12  post_author        1513 non-null   float64
#  13  post_date          1513 non-null   datetime64[ns]
#  14  post_date_gmt      1513 non-null   datetime64[ns]
# ...

# %%
df_cleaned.shape
# Out:
# (1513, 27)

# %%
df_cleaned.describe()
# Out:
#         product_id   onsale_web        price  stock_quantity  missing_flag  \
# count  1513.000000  1513.000000  1513.000000     1513.000000   1513.000000
# mean   5268.373166     0.868077    32.377515       28.956378      0.117515
# min    3847.000000     0.000000     5.200000        0.000000      0.000000
# 25%    4791.000000     1.000000    20.000000        8.000000      0.000000
# 50%    4958.000000     1.000000    23.680000       24.200000      0.000000
# 75%    5860.000000     1.000000    34.880000       42.200000      0.000000
# max    7338.000000     1.000000   225.000000      578.000000      1.000000
# std     775.593854     0.282642    22.958417       35.322311      0.267590
#
#        virtual  downloadable  rating_count  average_rating  total_sales  \
# count   1513.0        1513.0        1513.0          1513.0  1513.000000
# mean       0.0           0.0           0.0             0.0     4.002908
# min        0.0           0.0           0.0             0.0     0.000000
# ...

# %%
non_numeric_columns = df_cleaned.select_dtypes(exclude=['float', 'int']).columns
print("Non-numeric columns:", non_numeric_columns)

#  Drop non-numeric columns
df_numeric = df_cleaned.drop(columns=non_numeric_columns)

df_numeric.corr()
# Out:
# Non-numeric columns: Index(['stock_status', 'sku', 'post_date', 'post_date_gmt', 'post_title',
#        'post_status', 'comment_status', 'ping_status', 'post_name',
#        'post_modified', 'post_modified_gmt', 'guid', 'post_type'],
#       dtype='object')
#                 product_id  onsale_web     price  stock_quantity  \
# product_id        1.000000   -0.380800  0.118751       -0.116503
# onsale_web       -0.380800    1.000000 -0.099400        0.171987
# price             0.118751   -0.099400  1.000000       -0.326001
# stock_quantity   -0.116503    0.171987 -0.326001        1.000000
# missing_flag      0.390880   -0.898110  0.141059       -0.146414
# virtual                NaN         NaN       NaN             NaN
# downloadable           NaN         NaN       NaN             NaN
# rating_count           NaN         NaN       NaN             NaN
# average_rating         NaN         NaN       NaN             NaN
# total_sales       0.101676    0.012467 -0.060889        0.062267
# ...

# %%
# Identify non-numeric columns
non_numeric_columns = df_cleaned.select_dtypes(exclude=['float', 'int']).columns
print("Non-numeric columns:", non_numeric_columns)

#  Drop non-numeric columns
df_numeric = df_cleaned.drop(columns=non_numeric_columns)

#  Generate heatmap with numeric data
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
sns.heatmap(df_numeric.corr(), annot=True, cmap='coolwarm',
            annot_kws={"size": 8}, linewidths=0.5,
            xticklabels=45, yticklabels=45, fmt='.2f')
plt.show()
# Out:
# Non-numeric columns: Index(['stock_status', 'sku', 'post_date', 'post_date_gmt', 'post_title',
#        'post_status', 'comment_status', 'ping_status', 'post_name',
#        'post_modified', 'post_modified_gmt', 'guid', 'post_type'],
#       dtype='object')

# %%
# Example: Simple Linear Regression if applicable
from sklearn.linear_model import LinearRegression

# Assume 'price' is the target and 'stock_quantity' is a feature (as an example)
model = LinearRegression()
model.fit(df_cleaned[['stock_quantity']], df_cleaned['price'])

# Predicting and analyzing results
predictions = model.predict(df_cleaned[['stock_quantity']])
predictions
# Out:
# array([38.5131018 , 38.5131018 , 38.5131018 , ..., 29.57131468,
#        29.57131468, 29.57131468])

# %% [markdown]
#  Understand the distribution of price and stock_quantity

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['price'], kde=True)
plt.title('Price Distribution')
plt.show()

sns.histplot(df['stock_quantity'], kde=True)
plt.title('Stock Quantity Distribution')
plt.show()

# %% [markdown]
#  Investigate the relationship between price and stock_quantity.

# %%
plt.scatter(df_cleaned['price'], df_cleaned['stock_quantity'])
plt.title('Price vs. Stock Quantity')
plt.xlabel('Price')
plt.ylabel('Stock Quantity')
plt.show()

# %% [markdown]
# Correlation with Sale Status (onsale_web):
# Objective: Determine if products on sale (onsale_web) have significantly different price or stock_quantity compared to those not on sale.

# %%
df_cleaned.groupby('onsale_web')[['price', 'stock_quantity']].mean()

sns.boxplot(x='onsale_web', y='price', data=df_cleaned)
plt.title('Price vs On Sale Status')
plt.show()

sns.boxplot(x='onsale_web', y='stock_quantity', data=df_cleaned)
plt.title('Stock Quantity vs On Sale Status')
plt.show()

# %% [markdown]
# Categorize products based on price and stock_quantity to create insights like identifying premium, mid-range, and budget products.

# %%
# Example: Categorizing based on price
df_cleaned['price_category'] = pd.cut(df_cleaned['price'], bins=[0, 50, 150, 500], labels=['Budget', 'Mid-Range', 'Premium'])

# Count the number of products in each category
price_category_counts = df_cleaned['price_category'].value_counts()
price_category_counts
# Out:
# price_category
# Budget       1277
# Mid-Range     230
# Premium         6
# Name: count, dtype: int64

# %% [markdown]
#  Stock Optimization Analysis:
# Objective: Analyze stock_quantity to identify products that are overstocked or understocked.
# How: Compare stock quantities against average sales data (if available) or set thresholds.
# What to Look For: Products that may require restocking or markdowns to clear inventory.

# %%
# Example threshold analysis
low_stock = df_cleaned[df_cleaned['stock_quantity'] < 10]  # Threshold of 10 units
low_stock
high_stock = df_cleaned[df_cleaned['stock_quantity'] > 100]  # Threshold of 100 units
high_stock
# Out:
#      product_id  onsale_web  price  stock_quantity stock_status  missing_flag  \
# 21       4057.0         1.0    8.7           112.0      instock           0.0
# 22       4058.0         1.0    8.7           267.0      instock           0.0
# 31       4068.0         1.0   16.6           157.0      instock           0.0
# 83       4154.0         1.0    9.8           128.0      instock           0.0
# 100      4172.0         1.0    5.7           167.0      instock           0.0
# 103      4176.0         1.0   13.5           276.0      instock           0.0
# 104      4177.0         1.0   13.5           109.0      instock           0.0
# 108      4181.0         1.0   11.9           137.0      instock           0.0
# 115      4191.0         1.0    9.3           209.0      instock           0.0
# 122      4198.0         1.0    5.8           105.0      instock           0.0
# 123      4200.0         1.0    5.8           190.0      instock           0.0
# ...

# %%
plt.hist( ['low_stock', 'high_stock'], bins=20, edgecolor='k')
plt.xlabel('stock status')
plt.ylabel('high_stock')
plt.title('Distribution of Stock Quantity')
plt.show()

# %%
df_cleaned.columns
# Out:
# Index(['product_id', 'onsale_web', 'price', 'stock_quantity', 'stock_status',
#        'missing_flag', 'sku', 'virtual', 'downloadable', 'rating_count',
#        'average_rating', 'total_sales', 'post_author', 'post_date',
#        'post_date_gmt', 'post_title', 'post_status', 'comment_status',
#        'ping_status', 'post_name', 'post_modified', 'post_modified_gmt',
#        'post_parent', 'guid', 'menu_order', 'post_type', 'comment_count',
#        'price_category'],
#       dtype='object')

# %%
# Example: Rolling average (if there's time-based data like sales over months)
df_cleaned['sales_rolling'] = df_cleaned['total_sales'].rolling(window=3).mean()
plt.plot(df_cleaned['post_date'], df_cleaned['sales_rolling'])
figsize=(12,14)
plt.title('3-Month Rolling Average total_sales')
plt.show()

# %%
# Sales velocity example (assuming you have sales data)
df_cleaned['sales_velocity'] =df_cleaned['total_sales'] / df_cleaned['stock_quantity']
df_cleaned['sales_velocity']
# Out:
# 0            inf
# 1            inf
# 2            NaN
# 3            NaN
# 4            inf
#           ...
# 1508    0.181159
# 1509    0.000000
# 1510    0.000000
# 1511    0.000000
# 1512    0.000000
# Name: sales_velocity, Length: 1513, dtype: float64

# %%
df_cleaned
# Out:
#       product_id  onsale_web  price  stock_quantity stock_status  \
# 0         3847.0         1.0  24.20             0.0   outofstock
# 1         3849.0         1.0  34.30             0.0   outofstock
# 2         3850.0         1.0  20.80             0.0   outofstock
# 3         4032.0         1.0  14.10             0.0   outofstock
# 4         4039.0         1.0  46.00             0.0   outofstock
# ...          ...         ...    ...             ...          ...
# 1508      6335.0         1.0  28.32            27.6      instock
# 1509      4958.0         1.0  23.68            42.2      instock
# 1510      4958.0         1.0  23.68            42.2      instock
# 1511      4958.0         1.0  23.68            42.2      instock
# 1512      4958.0         1.0  23.68            42.2      instock
#
#       missing_flag                  sku  virtual  downloadable  rating_count  \
# 0              0.0  bon-cadeau-25-euros      0.0           0.0           0.0
# ...

# %%
plt.scatter(df_cleaned['stock_status'],['stock_quantity'],figsize=(10,10))
plt.title('stock_status vs stock_quantity')
plt.xlabel('Stock Status')
plt.ylabel('Stock Quantity')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-154-a3e30215a2f5> in <cell line: 1>()
# ----> 1 plt.scatter(df_cleaned['stock_status'],['stock_quantity'],figsize=(10,10))
#       2 plt.title('stock_status vs stock_quantity')
#       3 plt.xlabel('Stock Status')
#       4 plt.ylabel('Stock Quantity')
#       5 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2860         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2861         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2862     __ret = gca().scatter(
#    2863         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2864         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ...
